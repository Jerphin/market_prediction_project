# %%
import yfinance as yf
import pandas as pd

# %%
data = yf.download(
    "AAPL",
    period="5d",
    interval="5m"
)

print(data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                           Close        High         Low        Open  \
# Ticker                           AAPL        AAPL        AAPL        AAPL
# 2026-05-18 09:30:00-04:00  298.089996  300.630005  297.360107  300.239990
# 2026-05-18 09:35:00-04:00  298.592499  298.829987  297.540009  298.084991
# 2026-05-18 09:40:00-04:00  299.179993  299.459900  298.450012  298.589996
# 2026-05-18 09:45:00-04:00  298.070007  299.200012  298.019989  299.179993
# 2026-05-18 09:50:00-04:00  298.125000  298.250000  297.540009  298.065002
#
# Price                       Volume
# Ticker                        AAPL
# 2026-05-18 09:30:00-04:00  2816247
# 2026-05-18 09:35:00-04:00   666577
# 2026-05-18 09:40:00-04:00   492337
# 2026-05-18 09:45:00-04:00   479558
# 2026-05-18 09:50:00-04:00   425594

# %%
data.to_csv("../data/aapl_intraday.csv")

# %%
print(data.shape)
# Out:
# (390, 5)

# %%
print(data.isnull().sum())
# Out:
# Price   Ticker
# Close   AAPL      0
# High    AAPL      0
# Low     AAPL      0
# Open    AAPL      0
# Volume  AAPL      0
# dtype: int64

# %%
import matplotlib.pyplot as plt

data['Close'].plot(figsize=(12,6))
plt.title("AAPL Close Price")
plt.show()
