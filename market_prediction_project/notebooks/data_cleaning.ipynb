# %%
import pandas as pd

# %%
data = pd.read_csv("../data/aapl_intraday.csv")

# %%
print(data.head())
# Out:
#                        Price               Close                High  \
# 0                     Ticker                AAPL                AAPL
# 1  2026-05-18 09:30:00-04:00   298.0899963378906   300.6300048828125
# 2  2026-05-18 09:35:00-04:00   298.5924987792969   298.8299865722656
# 3  2026-05-18 09:40:00-04:00  299.17999267578125  299.45989990234375
# 4  2026-05-18 09:45:00-04:00  298.07000732421875  299.20001220703125
#
#                   Low                Open   Volume
# 0                AAPL                AAPL     AAPL
# 1    297.360107421875    300.239990234375  2816247
# 2   297.5400085449219   298.0849914550781   666577
# 3  298.45001220703125   298.5899963378906   492337
# 4   298.0199890136719  299.17999267578125   479558

# %%
print(data.shape)
# Out:
# (391, 6)

# %%
print(data.columns)
# Out:
# Index(['Price', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='str')

# %%
print(data.isnull().sum())
# Out:
# Price     0
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
print(data.duplicated().sum())
# Out:
# 0

# %%
data.iloc[:,0] = pd.to_datetime(data.iloc[:,0])
# Out:
# C:\Users\jerph\AppData\Local\Temp\ipykernel_29116\1829968765.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data.iloc[:,0] = pd.to_datetime(data.iloc[:,0])
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data.iloc[:,0] = pd.to_datetime(data.iloc[:,0])
#
# File c:\Users\jerph\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:1040, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, origin, cache)
#    1038         result = arg.map(cache_array)
#    1039     else:
# -> 1040         values = convert_listlike(arg._values, format)
#    1041         result = arg._constructor(values, index=arg.index, name=arg.name)
# ...

# %%
data = pd.read_csv(
    "../data/aapl_intraday.csv",
    skiprows=[1]
)

# %%
print(data.head())
# Out:
#                        Price       Close        High         Low        Open  \
# 0  2026-05-18 09:30:00-04:00  298.089996  300.630005  297.360107  300.239990
# 1  2026-05-18 09:35:00-04:00  298.592499  298.829987  297.540009  298.084991
# 2  2026-05-18 09:40:00-04:00  299.179993  299.459900  298.450012  298.589996
# 3  2026-05-18 09:45:00-04:00  298.070007  299.200012  298.019989  299.179993
# 4  2026-05-18 09:50:00-04:00  298.125000  298.250000  297.540009  298.065002
#
#     Volume
# 0  2816247
# 1   666577
# 2   492337
# 3   479558
# 4   425594

# %%
data.iloc[:,0] = pd.to_datetime(data.iloc[:,0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\jerph\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:2144, in _iLocIndexer._setitem_single_column(self, loc, value, plane_indexer)
#    2143 try:
# -> 2144     self.obj._mgr.column_setitem(
#    2145         loc, plane_indexer, value, inplace_only=True
#    2146     )
#    2147 except (ValueError, TypeError, LossySetitemError) as exc:
#    2148     # If we're setting an entire column and we can't do it inplace,
#    2149     #  then we can use value's dtype (or inferred dtype)
#    2150     #  instead of object
#
# File c:\Users\jerph\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1526, in BlockManager.column_setitem(self, loc, idx, value, inplace_only)
#    1525 if inplace_only:
# -> 1526     col_mgr.setitem_inplace(idx, value)
# ...

# %%
print(data.columns)
# Out:
# Index(['Price', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='str')

# %%
data["Price"] = pd.to_datetime(data["Price"])

# %%
data.rename(columns={"Price": "Datetime"}, inplace=True)

# %%
print(data.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Datetime  390 non-null    datetime64[us, UTC-04:00]
#  1   Close     390 non-null    float64
#  2   High      390 non-null    float64
#  3   Low       390 non-null    float64
#  4   Open      390 non-null    float64
#  5   Volume    390 non-null    int64
# dtypes: datetime64[us, UTC-04:00](1), float64(4), int64(1)
# memory usage: 18.4 KB
# None

# %%
data.to_csv("../data/aapl_cleaned.csv", index=False)
